# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities)
# Out:
# 611
# ['nelson bay', 'zhanatas', 'tazovskiy', 'puerto ayora', 'khatanga', 'kavali', 'canon city', 'viligili', 'port alfred', 'mgandu', 'rikitea', 'albany', 'balimo', 'qaanaaq', 'busselton', 'bambous virieux', 'ladysmith', 'kruisfontein', 'hobart', 'grimari', 'souillac', 'faanui', 'katsuura', 'cidreira', 'westport', 'hilo', 'illoqqortoormiut', 'bluff', 'cherskiy', 'thompson', 'ushuaia', 'dikson', 'chandbali', 'nikolskoye', 'agadez', 'provideniya', 'attawapiskat', 'georgetown', 'saldanha', 'quelimane', 'chicama', 'victoria', 'neiafu', 'hermanus', 'elesbao veloso', 'hithadhoo', 'lolua', 'kodiak', 'avarua', 'punta arenas', 'tshane', 'narsaq', 'semnan', 'san rafael', 'yerbogachen', 'nsanje', 'ostersund', 'jamestown', 'belushya guba', 'lubbock', 'tumannyy', 'camacha', 'samusu', 'san quintin', 'rivers', 'butaritari', 'pyay', 'saint george', 'lagoa', 'kosh-agach', 'yellowknife', 'aklavik', 'angoram', 'atuona', 'kapaa', 'inirida', 'jinchengjiang', 'ancud', 'ponta do sol', 'chuy', 'mao', 'new norfolk', 'eyl', 'pontianak', 'leningradskiy', 'diamantino', 'tevaitoa', 'arrecife', 'bredasdorp', 'mukdahan', 'longido', 'half moon bay', 'egvekinot', 'esperance', 'taolanaro', 'barentsburg', 'nouadhibou', 'namatanai', 'huarmey', 'tarudant', 'valdez', 'paramonga', 'tuktoyaktuk', 'castro', 'lebu', 'tura', 'vilyuysk', 'amderma', 'pisco', 'east london', 'torbay', 'mys shmidta', 'yarada', 'tambopata', 'mahebourg', 'fort dodge', 'louisbourg', 'palma di montechiaro', 'coahuayana', 'kahului', 'bucerias', 'caravelas', 'vaitupu', 'rudnya', 'vaini', 'beian', 'yakima', 'sinnamary', 'hearst', 'breyten', 'nongstoin', 'berlevag', 'mataura', 'kieta', 'jardim do serido', 'longyearbyen', 'tuatapere', 'teahupoo', 'tiksi', 'abu dhabi', 'saint-philippe', 'umzimvubu', 'port elizabeth', 'komsomolskiy', 'paso de los toros', 'padang', 'nicoya', 'oranjemund', 'pevek', 'portland', 'makueni', 'coihaique', 'asau', 'kemijarvi', 'laguna', 'sola', 'ahipara', 'nanae', 'lata', 'meghraj', 'cruzeiro do sul', 'norman wells', 'nizhniy kuranakh', 'cape town', 'ilulissat', 'seymchan', 'nizhneyansk', 'khvoynaya', 'araouane', 'byron bay', 'pacific grove', 'sandpoint', 'marsh harbour', 'buala', 'alice springs', 'borovskoy', 'dunedin', 'aksu', 'vytegra', 'saskylakh', 'palu', 'yambio', 'ugoofaaru', 'cayenne', 'san isidro', 'flinders', 'tiznit', 'menongue', 'preobrazheniye', 'namibe', 'najran', 'margate', 'nago', 'phan rang', 'yerofey pavlovich', 'iquique', 'phalodi', 'andevoranto', 'guerrero negro', 'narrabri', 'tadine', 'manzil salim', 'obo', 'melo', 'kaitangata', 'saveh', 'rockhampton', 'bor', 'anadyr', 'mar del plata', 'inhambane', 'nhulunbuy', 'vitim', 'clyde river', 'makakilo city', 'arraial do cabo', 'chokurdakh', 'watsa', 'tasiilaq', 'upernavik', 'pacora', 'severo-kurilsk', 'palmer', 'alekseyevka', 'ribeira grande', 'paracatu', 'westpunt', 'port lincoln', 'lavrentiya', 'vostok', 'manjacaze', 'sacramento', 'labuhan', 'constitucion', 'sentyabrskiy', 'samarai', 'takoradi', 'batetskiy', 'freetown', 'tawnat', 'wulanhaote', 'kazalinsk', 'airai', 'la ronge', 'barmer', 'aswan', 'koungou', 'vila velha', 'gorontalo', 'kavaratti', 'rawson', 'puerto escondido', 'vestmannaeyjar', 'maragogi', 'codrington', 'purpe', 'zalesovo', 'savannah bight', 'carnarvon', 'trairi', 'luderitz', 'grand gaube', 'xinzhi', 'hofn', 'srednekolymsk', 'praia da vitoria', 'peniche', 'nerchinskiy zavod', 'sargatskoye', 'lewiston', 'kurmanayevka', 'roald', 'dali', 'hovd', 'hillsborough', 'celestun', 'adrar', 'gambo', 'kenai', 'shimoda', 'faya', 'deputatskiy', 'gunjur', 'kirgiz-miyaki', 'lucapa', 'mehamn', 'luau', 'port-gentil', 'mossendjo', 'mayo', 'atar', 'oudtshoorn', 'kudahuvadhoo', 'fort-shevchenko', 'nome', 'gazanjyk', 'taoudenni', 'saleaula', 'kasongo', 'sumbe', 'bafoulabe', 'mayumba', 'trinidad', 'diffa', 'port blair', 'kasongo-lunda', 'mount gambier', 'bambanglipuro', 'bathsheba', 'comodoro rivadavia', 'santa isabel do rio negro', 'adre', 'charagua', 'valparaiso', 'tateyama', 'inta', 'ust-kamchatsk', 'letka', 'sumenep', ' ...

# %%
# test api call
# city_test = 'sussex'
# units = 'imperial'
# url = 'http://api.openweathermap.org/data/2.5/weather?'
# test_url = f"{url}q={city_test}&appid={weather_api_key}&units={units}"
# output = requests.get(test_url).json()
# city_name_test = output["name"]
# print(city_name_test)
# print(output)

# %%
# # test loop
# group_test = ['port blair', 'cap-chat', 'kutum', 'pemangkat', 'cairns']
# units = 'imperial'

# # Log file print statement
# print(f"Beginning Data Retrieval")
# print(f"------------------------")

# # Set call counter
# record = 0

# # Create lists to append API data
# city_name = []
# country = []
# date = []
# lat = []
# lng = []
# max_temp = []
# humidity = []
# wind_speed = []
# cloudiness = []

# url = 'http://api.openweathermap.org/data/2.5/weather?'
# # Loop through cities in city list
# for city in group_test:
#     test_url = f"{url}q={city}&appid={weather_api_key}&units={units}"

#     # Try statement to append calls where a value is found
#     try:
#         output = requests.get(test_url).json()
#         city_name.append(output["name"])
#         country.append(output["sys"]["country"])
#         date.append(output["dt"])
#         lat.append(output["coord"]["lat"])
#         lng.append(output["coord"]["lon"])
#         max_temp.append(output["main"]["temp_max"])
#         humidity.append(output["main"]["humidity"])
#         wind_speed.append(output["wind"]["speed"])
#         cloudiness.append(output["clouds"]["all"])
#         print(f"Processing Record {record} | {city}")
#         print(f"{url}&q={city}")
#         print(output)
        
#     # If no record found, skip to next call
#     except:
#         print(f"City not found. Skipping...")
        
#     # Increase counter by 1
#     record += 1
              
#     # Set wait in loop so as to exceed rate limit of api
#     time.sleep(1.0)
# print(" ---------- Data Retrieval Complete ---------- ")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import time

# %%
# Log file print statement
print(f"Beginning Data Retrieval")
print(f"------------------------")

# Set call counter
record = 0

# Create lists to append API data
city_name = []
country = []
date = []
lat = []
lng = []
max_temp = []
humidity = []
wind_speed = []
cloudiness = []

url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'

# Loop through cities in city list
for city in cities:
    call_url = f"{url}q={city}&appid={weather_api_key}&units={units}"

    # Try statement to append calls where a value is found
    try:
        output = requests.get(call_url).json()
        city_name.append(output["name"])
        country.append(output["sys"]["country"])
        date.append(output["dt"])
        lat.append(output["coord"]["lat"])
        lng.append(output["coord"]["lon"])
        max_temp.append(output["main"]["temp_max"])
        humidity.append(output["main"]["humidity"])
        wind_speed.append(output["wind"]["speed"])
        cloudiness.append(output["clouds"]["all"])
        print(f"Processing Record {record} | {city}")
        print(f"{url}&q={city}")
        
    # If no record found, skip to next call
    except:
        print(f"City not found. Skipping...")
        
    # Increase counter by 1
    record += 1
              
    # Set wait in loop so as to exceed rate limit of api
    time.sleep(1.0)
print(" ---------- Data Retrieval Complete ---------- ")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?&q=nelson bay
# City not found. Skipping...
# Processing Record 2 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=tazovskiy
# Processing Record 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 5 | kavali
# http://api.openweathermap.org/data/2.5/weather?&q=kavali
# Processing Record 6 | canon city
# http://api.openweathermap.org/data/2.5/weather?&q=canon city
# City not found. Skipping...
# Processing Record 8 | port alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 9 | mgandu
# http://api.openweathermap.org/data/2.5/weather?&q=mgandu
# Processing Record 10 | rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 11 | albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# City not found. Skipping...
# Processing Record 13 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 14 | busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 15 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 16 | ladysmith
# http://api.openweathermap.org/data/2.5/weather?&q=ladysmith
# Processing Record 17 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 18 | hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# City not found. Skipping...
# Processing Record 20 | souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 21 | faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 22 | katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 23 | cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 24 | westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# Processing Record 25 | hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# City not found. Skipping...
# Processing Record 27 | bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 28 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 29 | thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 30 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 31 | dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 32 | chandbali
# http://api.openweathermap.org/data/2.5/weather?&q=chandbali
# Processing Record 33 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 34 | agadez
# http://api.openweathermap.org/data/2.5/weather?&q=agadez
# Processing Record 35 | provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# City not found. Skipping...
# Processing Record 37 | georgetown
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 38 | saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 39 | quelimane
# http://api.openweathermap.org/data/2.5/weather?&q=quelimane
# Processing Record 40 | chicama
# http://api.openweathermap.org/data/2.5/weather?&q=chicama
# Processing Record 41 | victoria
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 42 | neiafu
# http://api.openweathermap.org/data/2.5/weather?&q=neiafu
# Processing Record 43 | hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 44 | elesbao veloso
# http://api.openweathermap.org/data/2.5/weather?&q=elesbao veloso
# Processing Record 45 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# City not found. Skipping...
# Processing Record 47 | kodiak
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 48 | avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 49 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 50 | tshane
# http://api.openweathermap.org/data/2.5/weather?&q=tshane
# Processing Record 51 | narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 52 | semnan
# http://api.openweathermap.org/data/2.5/weather?&q=semnan
# Processing Record 53 | san rafael
# http://api.openweathermap.org/data/2.5/weather?&q=san rafael
# Processing Record 54 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?&q=yerbogachen
# Processing Record 55 | nsanje
# http://api.openweathermap.org/data/2.5/weather?&q=nsanje
# Processing Record 56 | ostersund
# http://api.openweathermap.org/data/2.5/weather?&q=ostersund
# Processing Record 57 | jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# City not found. Skipping...
# Processing Record 59 | lubbock
# http://api.openweathermap.org/data/2.5/weather?&q=lubbock
# City not found. Skipping...
# Processing Record 61 | camacha
# http://api.openweathermap.org/data/2.5/weather?&q=camacha
# City not found. Skipping...
# Processing Record 63 | san quintin
# http://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 64 | rivers
# http://api.openweathermap.org/data/2.5/weather?&q=rivers
# Processing Record 65 | butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 66 | pyay
# http://api.openweathermap.org/data/2.5/weather?&q=pyay
# Processing Record 67 | saint george
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 68 | lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 69 | kosh-agach
# http://api.openweathermap.org/data/2.5/weather?&q=kosh-agach
# Processing Record 70 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 71 | aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 72 | angoram
# http://api.openweathermap.org/data/2.5/weather?&q=angoram
# Processing Record 73 | atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 74 | kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 75 | inirida
# http://api.openweathermap.org/data/2.5/weather?&q=inirida
# City not found. Skipping...
# Processing Record 77 | ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 78 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 79 | chuy
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 80 | mao
# http://api.openweathermap.org/data/2.5/weather?&q=mao
# Processing Record 81 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 82 | eyl
# http://api.openweathermap.org/data/2.5/weather?&q=eyl
# Processing Record 83 | pontianak
# http://api.openweathermap.org/data/2.5/weather?&q=pontianak
# Processing Record 84 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 85 | diamantino
# http://api.openweathermap.org/data/2.5/weather?&q=diamantino
# Processing Record 86 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?&q=tevaitoa
# Processing Record 87 | arrecife
# http://api.openweathermap.org/data/2.5/weather?&q=arrecife
# Processing Record 88 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 89 | mukdahan
# http://api.openweathermap.org/data/2.5/weather?&q=mukdahan
# Processing Record 90 | longido
# http://api.openweathermap.org/data/2.5/weather?&q=longido
# Processing Record 91 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# Processing Record 92 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 93 | esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 96 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# Processing Record 97 | namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 98 | huarmey
# http://api.openweathermap.org/data/2.5/weather?&q=huarmey
# City not found. Skipping...
# Processing Record 100 | valdez
# http://api.openweathermap.org/data/2.5/weather?&q=valdez
# Processing Record 101 | paramonga
# http://api.openweathermap.org/data/2.5/weather?&q=paramonga
# Processing Record 102 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 103 | castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 104 | lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 105 | tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 106 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=vilyuysk
# City not found. Skipping...
# Processing Record 108 | pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 109 | east london
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 110 | torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# City not found. Skipping...
# Processing Record 112 | yarada
# http://api.openweathermap.org/data/2.5/weather?&q=yarada
# Processing Record 113 | tambopata
# http://api.openweathermap.org/data/2.5/weather?&q=tambopata
# Processing Record 114 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 115 | fort dodge
# http://api.openweathermap.org/data/2.5/weather?&q=fort dodge
# City not found. Skipping...
# Processing Record 117 | palma di montechiaro
# http://api.openweathermap.org/data/2.5/weather?&q=palma di montechiaro
# Processing Record 118 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?&q=coahuayana
# Processing Record 119 | kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 120 | bucerias
# http://api.openweathermap.org/data/2.5/weather?&q=bucerias
# Processing Record 121 | caravelas
# http://api.openweathermap.org/data/2.5/weather?&q=caravelas
# City not found. Skipping...
# Processing Record 123 | rudnya
# http://api.openweathermap.org/data/2.5/weather?&q=rudnya
# Processing Record 124 | vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 125 | beian
# http://api.openweathermap.org/data/2.5/weather?&q=beian
# Processing Record 126 | yakima
# http://api.openweathermap.org/data/2.5/weather?&q=yakima
# Processing Record 127 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# Processing Record 128 | hearst
# http://api.openweathermap.org/data/2.5/weather?&q=hearst
# Processing Record 129 | breyten
# http://api.openweathermap.org/data/2.5/weather?&q=breyten
# Processing Record 130 | nongstoin
# http://api.openweathermap.org/data/2.5/weather?&q=nongstoin
# Processing Record 131 | berlevag
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 132 | mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 133 | kieta
# http://api.openweathermap.org/data/2.5/weather?&q=kieta
# Processing Record 134 | jardim do serido
# http://api.openweathermap.org/data/2.5/weather?&q=jardim do serido
# Processing Record 135 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 136 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 137 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?&q=teahupoo
# Processing Record 138 | tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 139 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?&q=abu dhabi
# Processing Record 140 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# City not found. Skipping...
# Processing Record 142 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 143 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?&q=komsomolskiy
# Processing Record 144 | paso de los toros
# http://api.openweathermap.org/data/2.5/weather?&q=paso de los toros
# Processing Record 145 | padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# Processing Record 146 | nicoya
# http://api.openweathermap.org/data/2.5/weather?&q=nicoya
# Processing Record 147 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?&q=oranjemund
# Processing Record 148 | pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 149 | portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 150 | makueni
# http://api.openweathermap.org/data/2.5/weather?&q=makueni
# Processing Record 151 | coihaique
# http://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 152 | asau
# http://api.openweathermap.org/data/2.5/weather?&q=asau
# Processing Record 153 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?&q=kemijarvi
# Processing Record 154 | laguna
# http://api.openweathermap.org/data/2.5/weather?&q=laguna
# Processing Record 155 | sola
# http://api.openweathermap.org/data/2.5/weather?&q=sola
# Processing Record 156 | ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 157 | nanae
# http://api.openweathermap.org/data/2.5/weather?&q=nanae
# Processing Record 158 | lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 159 | meghraj
# http://api.openweathermap.org/data/2.5/weather?&q=meghraj
# Processing Record 160 | cruzeiro do sul
# http://api.openweathermap.org/data/2.5/weather?&q=cruzeiro do sul
# Processing Record 161 | norman wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 162 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?&q=nizhniy kuranakh
# Processing Record 163 | cape town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 164 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 165 | seymchan
# http://api.openweathermap.org/data/2.5/weather?&q=seymchan
# City not found. Skipping...
# Processing Record 167 | khvoynaya
# http://api.openweathermap.org/data/2.5/weather?&q=khvoynaya
# Processing Record 168 | araouane
# http://api.openweathermap.org/data/2.5/weather?&q=araouane
# Processing Record 169 | byron bay
# http://api.openweathermap.org/data/2.5/weather?&q=byron bay
# Processing Record 170 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 171 | sandpoint
# http://api.openweathermap.org/data/2.5/weather?&q=sandpoint
# Processing Record 172 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?&q=marsh harbour
# Processing Record 173 | buala
# http://api.openweathermap.org/data/2.5/weather?&q=buala
# Processing Record 174 | alice springs
# http://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 175 | borovskoy
# http://api.openweathermap.org/data/2.5/weather?&q=borovskoy
# Processing Record 176 | dunedin
# http://api.openweathermap.org/data/2.5/weather?&q=dunedin
# Processing Record 177 | aksu
# http://api.openweathermap.org/data/2.5/weather?&q=aksu
# Processing Record 178 | vytegra
# http://api.openweathermap.org/data/2.5/weather?&q=vytegra
# Processing Record 179 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 180 | palu
# http://api.openweathermap.org/data/2.5/weather?&q=palu
# Processing Record 181 | yambio
# http://api.openweathermap.org/data/2.5/weather?&q=yambio
# Processing Record 182 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?&q=ugoofaaru
# Processing Record 183 | cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 184 | san isidro
# http://api.openweathermap.org/data/2.5/weather?&q=san isidro
# Processing Record 185 | flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 186 | tiznit
# http://api.openweathermap.org/data/2.5/weather?&q=tiznit
# Processing Record 187 | menongue
# http://api.openweathermap.org/data/2.5/weather?&q=menongue
# Processing Record 188 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?&q=preobrazheniye
# Processing Record 189 | namibe
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 190 | najran
# http://api.openweathermap.org/data/2.5/weather?&q=najran
# Processing Record 191 | margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 192 | nago
# http://api.openweathermap.org/data/2.5/weather?&q=nago
# City not found. Skipping...
# Processing Record 194 | yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?&q=yerofey pavlovich
# Processing Record 195 | iquique
# http://api.openweathermap.org/data/2.5/weather?&q=iquique
# Processing Record 196 | phalodi
# http://api.openweathermap.org/data/2.5/weather?&q=phalodi
# City not found. Skipping...
# Processing Record 198 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# Processing Record 199 | narrabri
# http://api.openweathermap.org/data/2.5/weather?&q=narrabri
# Processing Record 200 | tadine
# http://api.openweathermap.org/data/2.5/weather?&q=tadine
# Processing Record 201 | manzil salim
# http://api.openweathermap.org/data/2.5/weather?&q=manzil salim
# Processing Record 202 | obo
# http://api.openweathermap.org/data/2.5/weather?&q=obo
# Processing Record 203 | melo
# http://api.openweathermap.org/data/2.5/weather?&q=melo
# Processing Record 204 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 205 | saveh
# http://api.openweathermap.org/data/2.5/weather?&q=saveh
# Processing Record 206 | rockhampton
# http://api.openweathermap.org/data/2.5/weather?&q=rockhampton
# Processing Record 207 | bor
# http://api.openweathermap.org/data/2.5/weather?&q=bor
# Processing Record 208 | anadyr
# http://api.openweathermap.org/data/2.5/weather?&q=anadyr
# Processing Record 209 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 210 | inhambane
# http://api.openweathermap.org/data/2.5/weather?&q=inhambane
# Processing Record 211 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?&q=nhulunbuy
# Processing Record 212 | vitim
# http://api.openweathermap.org/data/2.5/weather?&q=vitim
# Processing Record 213 | clyde river
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 214 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?&q=makakilo city
# Processing Record 215 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 216 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 217 | watsa
# http://api.openweathermap.org/data/2.5/weather?&q=watsa
# Processing Record 218 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 219 | upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 220 | pacora
# http://api.openweathermap.org/data/2.5/weather?&q=pacora
# Processing Record 221 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 222 | palmer
# http://api.openweathermap.org/data/2.5/weather?&q=palmer
# Processing Record 223 | alekseyevka
# http://api.openweathermap.org/data/2.5/weather?&q=alekseyevka
# Processing Record 224 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 225 | paracatu
# http://api.openweathermap.org/data/2.5/weather?&q=paracatu
# City not found. Skipping...
# Processing Record 227 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 228 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 229 | vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 230 | manjacaze
# http://api.openweathermap.org/data/2.5/weather?&q=manjacaze
# Processing Record 231 | sacramento
# http://api.openweathermap.org/data/2.5/weather?&q=sacramento
# Processing Record 232 | labuhan
# http://api.openweathermap.org/data/2.5/weather?&q=labuhan
# Processing Record 233 | constitucion
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# City not found. Skipping...
# Processing Record 235 | samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 236 | takoradi
# http://api.openweathermap.org/data/2.5/weather?&q=takoradi
# Processing Record 237 | batetskiy
# http://api.openweathermap.org/data/2.5/weather?&q=batetskiy
# Processing Record 238 | freetown
# http://api.openweathermap.org/data/2.5/weather?&q=freetown
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 242 | airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 243 | la ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 244 | barmer
# http://api.openweathermap.org/data/2.5/weather?&q=barmer
# Processing Record 245 | aswan
# http://api.openweathermap.org/data/2.5/weather?&q=aswan
# Processing Record 246 | koungou
# http://api.openweathermap.org/data/2.5/weather?&q=koungou
# Processing Record 247 | vila velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# Processing Record 248 | gorontalo
# http://api.openweathermap.org/data/2.5/weather?&q=gorontalo
# Processing Record 249 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 250 | rawson
# http://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 251 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?&q=puerto escondido
# Processing Record 252 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 253 | maragogi
# http://api.openweathermap.org/data/2.5/weather?&q=maragogi
# Processing Record 254 | codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 255 | purpe
# http://api.openweathermap.org/data/2.5/weather?&q=purpe
# Processing Record 256 | zalesovo
# http://api.openweathermap.org/data/2.5/weather?&q=zalesovo
# Processing Record 257 | savannah bight
# http://api.openweathermap.org/data/2.5/weather?&q=savannah bight
# Processing Record 258 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 259 | trairi
# http://api.openweathermap.org/data/2.5/weather?&q=trairi
# Processing Record 260 | luderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 261 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?&q=grand gaube
# Processing Record 262 | xinzhi
# http://api.openweathermap.org/data/2.5/weather?&q=xinzhi
# Processing Record 263 | hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# Processing Record 264 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 265 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?&q=praia da vitoria
# Processing Record 266 | peniche
# http://api.openweathermap.org/data/2.5/weather?&q=peniche
# Processing Record 267 | nerchinskiy zavod
# http://api.openweathermap.org/data/2.5/weather?&q=nerchinskiy zavod
# Processing Record 268 | sargatskoye
# http://api.openweathermap.org/data/2.5/weather?&q=sargatskoye
# Processing Record 269 | lewiston
# http://api.openweathermap.org/data/2.5/weather?&q=lewiston
# Processing Record 270 | kurmanayevka
# http://api.openweathermap.org/data/2.5/weather?&q=kurmanayevka
# Processing Record 271 | roald
# http://api.openweathermap.org/data/2.5/weather?&q=roald
# Processing Record 272 | dali
# http://api.openweathermap.org/data/2.5/weather?&q=dali
# Processing Record 273 | hovd
# http://api.openweathermap.org/data/2.5/weather?&q=hovd
# Processing Record 274 | hillsborough
# http://api.openweathermap.org/data/2.5/weather?&q=hillsborough
# Processing Record 275 | celestun
# http://api.openweathermap.org/data/2.5/weather?&q=celestun
# Processing Record 276 | adrar
# http://api.openweathermap.org/data/2.5/weather?&q=adrar
# Processing Record 277 | gambo
# http://api.openweathermap.org/data/2.5/weather?&q=gambo
# Processing Record 278 | kenai
# http://api.openweathermap.org/data/2.5/weather?&q=kenai
# Processing Record 279 | shimoda
# http://api.openweathermap.org/data/2.5/weather?&q=shimoda
# Processing Record 280 | faya
# http://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 281 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 282 | gunjur
# http://api.openweathermap.org/data/2.5/weather?&q=gunjur
# Processing Record 283 | kirgiz-miyaki
# http://api.openweathermap.org/data/2.5/weather?&q=kirgiz-miyaki
# Processing Record 284 | lucapa
# http://api.openweathermap.org/data/2.5/weather?&q=lucapa
# Processing Record 285 | mehamn
# http://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 286 | luau
# http://api.openweathermap.org/data/2.5/weather?&q=luau
# Processing Record 287 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# Processing Record 288 | mossendjo
# http://api.openweathermap.org/data/2.5/weather?&q=mossendjo
# Processing Record 289 | mayo
# http://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 290 | atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 291 | oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?&q=oudtshoorn
# Processing Record 292 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=kudahuvadhoo
# Processing Record 293 | fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?&q=fort-shevchenko
# Processing Record 294 | nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# Processing Record 295 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?&q=gazanjyk
# Processing Record 296 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?&q=taoudenni
# City not found. Skipping...
# Processing Record 298 | kasongo
# http://api.openweathermap.org/data/2.5/weather?&q=kasongo
# Processing Record 299 | sumbe
# http://api.openweathermap.org/data/2.5/weather?&q=sumbe
# Processing Record 300 | bafoulabe
# http://api.openweathermap.org/data/2.5/weather?&q=bafoulabe
# Processing Record 301 | mayumba
# http://api.openweathermap.org/data/2.5/weather?&q=mayumba
# Processing Record 302 | trinidad
# http://api.openweathermap.org/data/2.5/weather?&q=trinidad
# Processing Record 303 | diffa
# http://api.openweathermap.org/data/2.5/weather?&q=diffa
# Processing Record 304 | port blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 305 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?&q=kasongo-lunda
# Processing Record 306 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?&q=mount gambier
# Processing Record 307 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?&q=bambanglipuro
# Processing Record 308 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 309 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# Processing Record 310 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?&q=santa isabel do rio negro
# Processing Record 311 | adre
# http://api.openweathermap.org/data/2.5/weather?&q=adre
# Processing Record 312 | charagua
# http://api.openweathermap.org/data/2.5/weather?&q=charagua
# Processing Record 313 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?&q=valparaiso
# Processing Record 314 | tateyama
# http://api.openweathermap.org/data/2.5/weather?&q=tateyama
# Processing Record 315 | inta
# http://api.openweathermap.org/data/2.5/weather?&q=inta
# City not found. Skipping...
# Processing Record 317 | letka
# http://api.openweathermap.org/data/2.5/weather?&q=letka
# Processing Record 318 | sumenep
# http://api.openweathermap.org/data/2.5/weather?&q=sumenep
# Processing Record 319 | tabuk
# http://api.openweathermap.org/data/2.5/weather?&q=tabuk
# Processing Record 320 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?&q=qasigiannguit
# Processing Record 321 | arauca
# http://api.openweathermap.org/data/2.5/weather?&q=arauca
# Processing Record 322 | tashtagol
# http://api.openweathermap.org/data/2.5/weather?&q=tashtagol
# Processing Record 323 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# Processing Record 324 | naze
# http://api.openweathermap.org/data/2.5/weather?&q=naze
# Processing Record 325 | kachug
# http://api.openweathermap.org/data/2.5/weather?&q=kachug
# City not found. Skipping...
# Processing Record 327 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?&q=port shepstone
# Processing Record 328 | tacuarembo
# http://api.openweathermap.org/data/2.5/weather?&q=tacuarembo
# Processing Record 329 | pingdingshan
# http://api.openweathermap.org/data/2.5/weather?&q=pingdingshan
# Processing Record 330 | lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 331 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# Processing Record 332 | saint-paul
# http://api.openweathermap.org/data/2.5/weather?&q=saint-paul
# Processing Record 333 | roma
# http://api.openweathermap.org/data/2.5/weather?&q=roma
# Processing Record 334 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# Processing Record 335 | broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# City not found. Skipping...
# Processing Record 337 | jacksonville
# http://api.openweathermap.org/data/2.5/weather?&q=jacksonville
# Processing Record 338 | barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 339 | harindanga
# http://api.openweathermap.org/data/2.5/weather?&q=harindanga
# City not found. Skipping...
# Processing Record 341 | bilibino
# http://api.openweathermap.org/data/2.5/weather?&q=bilibino
# Processing Record 342 | binga
# http://api.openweathermap.org/data/2.5/weather?&q=binga
# Processing Record 343 | nyagan
# http://api.openweathermap.org/data/2.5/weather?&q=nyagan
# Processing Record 344 | wentzville
# http://api.openweathermap.org/data/2.5/weather?&q=wentzville
# Processing Record 345 | ahome
# http://api.openweathermap.org/data/2.5/weather?&q=ahome
# Processing Record 346 | zalari
# http://api.openweathermap.org/data/2.5/weather?&q=zalari
# Processing Record 347 | tabou
# http://api.openweathermap.org/data/2.5/weather?&q=tabou
# Processing Record 348 | yelandur
# http://api.openweathermap.org/data/2.5/weather?&q=yelandur
# Processing Record 349 | parauna
# http://api.openweathermap.org/data/2.5/weather?&q=parauna
# Processing Record 350 | maine-soroa
# http://api.openweathermap.org/data/2.5/weather?&q=maine-soroa
# Processing Record 351 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?&q=lac du bonnet
# Processing Record 352 | yumen
# http://api.openweathermap.org/data/2.5/weather?&q=yumen
# Processing Record 353 | ola
# http://api.openweathermap.org/data/2.5/weather?&q=ola
# Processing Record 354 | geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 355 | bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 356 | eskisehir
# http://api.openweathermap.org/data/2.5/weather?&q=eskisehir
# Processing Record 357 | north bay
# http://api.openweathermap.org/data/2.5/weather?&q=north bay
# Processing Record 358 | arco
# http://api.openweathermap.org/data/2.5/weather?&q=arco
# Processing Record 359 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# Processing Record 360 | pingliang
# http://api.openweathermap.org/data/2.5/weather?&q=pingliang
# Processing Record 361 | shihezi
# http://api.openweathermap.org/data/2.5/weather?&q=shihezi
# Processing Record 362 | tobermory
# http://api.openweathermap.org/data/2.5/weather?&q=tobermory
# Processing Record 363 | kirakira
# http://api.openweathermap.org/data/2.5/weather?&q=kirakira
# Processing Record 364 | atambua
# http://api.openweathermap.org/data/2.5/weather?&q=atambua
# City not found. Skipping...
# Processing Record 366 | acarau
# http://api.openweathermap.org/data/2.5/weather?&q=acarau
# Processing Record 367 | bubaque
# http://api.openweathermap.org/data/2.5/weather?&q=bubaque
# Processing Record 368 | birin
# http://api.openweathermap.org/data/2.5/weather?&q=birin
# Processing Record 369 | mairana
# http://api.openweathermap.org/data/2.5/weather?&q=mairana
# Processing Record 370 | acapulco
# http://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 371 | baie-comeau
# http://api.openweathermap.org/data/2.5/weather?&q=baie-comeau
# City not found. Skipping...
# Processing Record 373 | wenatchee
# http://api.openweathermap.org/data/2.5/weather?&q=wenatchee
# Processing Record 374 | fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 375 | sonoma
# http://api.openweathermap.org/data/2.5/weather?&q=sonoma
# Processing Record 376 | krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?&q=krasnovishersk
# Processing Record 377 | jiwani
# http://api.openweathermap.org/data/2.5/weather?&q=jiwani
# Processing Record 378 | fallon
# http://api.openweathermap.org/data/2.5/weather?&q=fallon
# Processing Record 379 | san patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 380 | olinda
# http://api.openweathermap.org/data/2.5/weather?&q=olinda
# City not found. Skipping...
# Processing Record 382 | qiongshan
# http://api.openweathermap.org/data/2.5/weather?&q=qiongshan
# Processing Record 383 | sangar
# http://api.openweathermap.org/data/2.5/weather?&q=sangar
# Processing Record 384 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?&q=hammerfest
# Processing Record 385 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# Processing Record 386 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# Processing Record 387 | port hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 388 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 389 | asfi
# http://api.openweathermap.org/data/2.5/weather?&q=asfi
# Processing Record 390 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?&q=ekhabi
# Processing Record 391 | el tigre
# http://api.openweathermap.org/data/2.5/weather?&q=el tigre
# Processing Record 392 | alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 393 | reconquista
# http://api.openweathermap.org/data/2.5/weather?&q=reconquista
# Processing Record 394 | calmar
# http://api.openweathermap.org/data/2.5/weather?&q=calmar
# Processing Record 395 | dukat
# http://api.openweathermap.org/data/2.5/weather?&q=dukat
# Processing Record 396 | san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?&q=san rafael del sur
# Processing Record 397 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?&q=plettenberg bay
# Processing Record 398 | lamu
# http://api.openweathermap.org/data/2.5/weather?&q=lamu
# Processing Record 399 | misratah
# http://api.openweathermap.org/data/2.5/weather?&q=misratah
# Processing Record 400 | farah
# http://api.openweathermap.org/data/2.5/weather?&q=farah
# Processing Record 401 | taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 402 | ranot
# http://api.openweathermap.org/data/2.5/weather?&q=ranot
# Processing Record 403 | corowa
# http://api.openweathermap.org/data/2.5/weather?&q=corowa
# Processing Record 404 | samana
# http://api.openweathermap.org/data/2.5/weather?&q=samana
# Processing Record 405 | jalu
# http://api.openweathermap.org/data/2.5/weather?&q=jalu
# Processing Record 406 | avera
# http://api.openweathermap.org/data/2.5/weather?&q=avera
# City not found. Skipping...
# Processing Record 408 | conde
# http://api.openweathermap.org/data/2.5/weather?&q=conde
# Processing Record 409 | goundam
# http://api.openweathermap.org/data/2.5/weather?&q=goundam
# Processing Record 410 | akyab
# http://api.openweathermap.org/data/2.5/weather?&q=akyab
# Processing Record 411 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?&q=ahuimanu
# Processing Record 412 | abancay
# http://api.openweathermap.org/data/2.5/weather?&q=abancay
# Processing Record 413 | bitam
# http://api.openweathermap.org/data/2.5/weather?&q=bitam
# Processing Record 414 | springbok
# http://api.openweathermap.org/data/2.5/weather?&q=springbok
# Processing Record 415 | wanaka
# http://api.openweathermap.org/data/2.5/weather?&q=wanaka
# Processing Record 416 | kanker
# http://api.openweathermap.org/data/2.5/weather?&q=kanker
# Processing Record 417 | emerald
# http://api.openweathermap.org/data/2.5/weather?&q=emerald
# Processing Record 418 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?&q=kangaatsiaq
# Processing Record 419 | lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 420 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?&q=shubarshi
# Processing Record 421 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?&q=sao jose da coroa grande
# Processing Record 422 | teguldet
# http://api.openweathermap.org/data/2.5/weather?&q=teguldet
# Processing Record 423 | kidal
# http://api.openweathermap.org/data/2.5/weather?&q=kidal
# Processing Record 424 | altay
# http://api.openweathermap.org/data/2.5/weather?&q=altay
# Processing Record 425 | te anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 426 | atasu
# http://api.openweathermap.org/data/2.5/weather?&q=atasu
# Processing Record 427 | berovo
# http://api.openweathermap.org/data/2.5/weather?&q=berovo
# Processing Record 428 | lemoore
# http://api.openweathermap.org/data/2.5/weather?&q=lemoore
# City not found. Skipping...
# Processing Record 430 | moree
# http://api.openweathermap.org/data/2.5/weather?&q=moree
# Processing Record 431 | sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 432 | muisne
# http://api.openweathermap.org/data/2.5/weather?&q=muisne
# Processing Record 433 | south venice
# http://api.openweathermap.org/data/2.5/weather?&q=south venice
# Processing Record 434 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# Processing Record 435 | boden
# http://api.openweathermap.org/data/2.5/weather?&q=boden
# Processing Record 436 | liverpool
# http://api.openweathermap.org/data/2.5/weather?&q=liverpool
# Processing Record 437 | yulara
# http://api.openweathermap.org/data/2.5/weather?&q=yulara
# Processing Record 438 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?&q=bengkulu
# Processing Record 439 | okitipupa
# http://api.openweathermap.org/data/2.5/weather?&q=okitipupa
# Processing Record 440 | richards bay
# http://api.openweathermap.org/data/2.5/weather?&q=richards bay
# Processing Record 441 | hami
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 442 | balapur
# http://api.openweathermap.org/data/2.5/weather?&q=balapur
# Processing Record 443 | shenkursk
# http://api.openweathermap.org/data/2.5/weather?&q=shenkursk
# Processing Record 444 | yablonovo
# http://api.openweathermap.org/data/2.5/weather?&q=yablonovo
# Processing Record 445 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?&q=pitimbu
# Processing Record 446 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?&q=myitkyina
# Processing Record 447 | ruidoso
# http://api.openweathermap.org/data/2.5/weather?&q=ruidoso
# Processing Record 448 | rudbar
# http://api.openweathermap.org/data/2.5/weather?&q=rudbar
# Processing Record 449 | balaipungut
# http://api.openweathermap.org/data/2.5/weather?&q=balaipungut
# Processing Record 450 | sorochinsk
# http://api.openweathermap.org/data/2.5/weather?&q=sorochinsk
# Processing Record 451 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?&q=ust-maya
# Processing Record 452 | kyaikto
# http://api.openweathermap.org/data/2.5/weather?&q=kyaikto
# Processing Record 453 | sungairaya
# http://api.openweathermap.org/data/2.5/weather?&q=sungairaya
# Processing Record 454 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?&q=ghanzi
# Processing Record 455 | erdenet
# http://api.openweathermap.org/data/2.5/weather?&q=erdenet
# Processing Record 456 | watrous
# http://api.openweathermap.org/data/2.5/weather?&q=watrous
# Processing Record 457 | honiara
# http://api.openweathermap.org/data/2.5/weather?&q=honiara
# Processing Record 458 | carnot
# http://api.openweathermap.org/data/2.5/weather?&q=carnot
# Processing Record 459 | biak
# http://api.openweathermap.org/data/2.5/weather?&q=biak
# Processing Record 460 | riohacha
# http://api.openweathermap.org/data/2.5/weather?&q=riohacha
# Processing Record 461 | innisfail
# http://api.openweathermap.org/data/2.5/weather?&q=innisfail
# City not found. Skipping...
# Processing Record 463 | mindelo
# http://api.openweathermap.org/data/2.5/weather?&q=mindelo
# City not found. Skipping...
# Processing Record 465 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 466 | taybad
# http://api.openweathermap.org/data/2.5/weather?&q=taybad
# Processing Record 467 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=thinadhoo
# Processing Record 468 | starosubkhangulovo
# http://api.openweathermap.org/data/2.5/weather?&q=starosubkhangulovo
# Processing Record 469 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?&q=hargeysa
# Processing Record 470 | morgan city
# http://api.openweathermap.org/data/2.5/weather?&q=morgan city
# Processing Record 471 | brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 472 | chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 473 | yangambi
# http://api.openweathermap.org/data/2.5/weather?&q=yangambi
# Processing Record 474 | talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 475 | rudarpur
# http://api.openweathermap.org/data/2.5/weather?&q=rudarpur
# Processing Record 476 | kizukuri
# http://api.openweathermap.org/data/2.5/weather?&q=kizukuri
# Processing Record 477 | sisophon
# http://api.openweathermap.org/data/2.5/weather?&q=sisophon
# Processing Record 478 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 479 | lyskovo
# http://api.openweathermap.org/data/2.5/weather?&q=lyskovo
# Processing Record 480 | kota bahru
# http://api.openweathermap.org/data/2.5/weather?&q=kota bahru
# Processing Record 481 | eloy
# http://api.openweathermap.org/data/2.5/weather?&q=eloy
# Processing Record 482 | sierra vista
# http://api.openweathermap.org/data/2.5/weather?&q=sierra vista
# Processing Record 483 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 484 | sistranda
# http://api.openweathermap.org/data/2.5/weather?&q=sistranda
# Processing Record 485 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?&q=dicabisagan
# Processing Record 486 | pushkino
# http://api.openweathermap.org/data/2.5/weather?&q=pushkino
# Processing Record 487 | avondale
# http://api.openweathermap.org/data/2.5/weather?&q=avondale
# Processing Record 488 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?&q=krasnoselkup
# Processing Record 489 | vung tau
# http://api.openweathermap.org/data/2.5/weather?&q=vung tau
# Processing Record 490 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?&q=boyolangu
# Processing Record 491 | mecca
# http://api.openweathermap.org/data/2.5/weather?&q=mecca
# Processing Record 492 | mirskoy
# http://api.openweathermap.org/data/2.5/weather?&q=mirskoy
# Processing Record 493 | omboue
# http://api.openweathermap.org/data/2.5/weather?&q=omboue
# Processing Record 494 | tupiza
# http://api.openweathermap.org/data/2.5/weather?&q=tupiza
# Processing Record 495 | corpus christi
# http://api.openweathermap.org/data/2.5/weather?&q=corpus christi
# Processing Record 496 | rodeo
# http://api.openweathermap.org/data/2.5/weather?&q=rodeo
# Processing Record 497 | ormara
# http://api.openweathermap.org/data/2.5/weather?&q=ormara
# Processing Record 498 | coruripe
# http://api.openweathermap.org/data/2.5/weather?&q=coruripe
# Processing Record 499 | jatai
# http://api.openweathermap.org/data/2.5/weather?&q=jatai
# Processing Record 500 | sohag
# http://api.openweathermap.org/data/2.5/weather?&q=sohag
# Processing Record 501 | doha
# http://api.openweathermap.org/data/2.5/weather?&q=doha
# Processing Record 502 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?&q=fort nelson
# Processing Record 503 | san lawrenz
# http://api.openweathermap.org/data/2.5/weather?&q=san lawrenz
# Processing Record 504 | salina
# http://api.openweathermap.org/data/2.5/weather?&q=salina
# City not found. Skipping...
# Processing Record 506 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?&q=abu samrah
# City not found. Skipping...
# Processing Record 508 | karaton
# http://api.openweathermap.org/data/2.5/weather?&q=karaton
# Processing Record 509 | villa carlos paz
# http://api.openweathermap.org/data/2.5/weather?&q=villa carlos paz
# Processing Record 510 | touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 511 | puerto pailas
# http://api.openweathermap.org/data/2.5/weather?&q=puerto pailas
# Processing Record 512 | natal
# http://api.openweathermap.org/data/2.5/weather?&q=natal
# Processing Record 513 | paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 514 | bereda
# http://api.openweathermap.org/data/2.5/weather?&q=bereda
# Processing Record 515 | riyadh
# http://api.openweathermap.org/data/2.5/weather?&q=riyadh
# Processing Record 516 | flin flon
# http://api.openweathermap.org/data/2.5/weather?&q=flin flon
# Processing Record 517 | apatity
# http://api.openweathermap.org/data/2.5/weather?&q=apatity
# Processing Record 518 | carutapera
# http://api.openweathermap.org/data/2.5/weather?&q=carutapera
# Processing Record 519 | skwierzyna
# http://api.openweathermap.org/data/2.5/weather?&q=skwierzyna
# Processing Record 520 | isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 521 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# Processing Record 522 | zhongshu
# http://api.openweathermap.org/data/2.5/weather?&q=zhongshu
# City not found. Skipping...
# Processing Record 524 | glendive
# http://api.openweathermap.org/data/2.5/weather?&q=glendive
# Processing Record 525 | broken hill
# http://api.openweathermap.org/data/2.5/weather?&q=broken hill
# Processing Record 526 | progress
# http://api.openweathermap.org/data/2.5/weather?&q=progress
# Processing Record 527 | dalby
# http://api.openweathermap.org/data/2.5/weather?&q=dalby
# Processing Record 528 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?&q=kungurtug
# Processing Record 529 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?&q=berdigestyakh
# Processing Record 530 | nanaimo
# http://api.openweathermap.org/data/2.5/weather?&q=nanaimo
# Processing Record 531 | carballo
# http://api.openweathermap.org/data/2.5/weather?&q=carballo
# Processing Record 532 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 533 | college
# http://api.openweathermap.org/data/2.5/weather?&q=college
# Processing Record 534 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# Processing Record 535 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# Processing Record 536 | paracuru
# http://api.openweathermap.org/data/2.5/weather?&q=paracuru
# Processing Record 537 | wilmington
# http://api.openweathermap.org/data/2.5/weather?&q=wilmington
# Processing Record 538 | dalvik
# http://api.openweathermap.org/data/2.5/weather?&q=dalvik
# Processing Record 539 | nantucket
# http://api.openweathermap.org/data/2.5/weather?&q=nantucket
# Processing Record 540 | port hedland
# http://api.openweathermap.org/data/2.5/weather?&q=port hedland
# Processing Record 541 | yurimaguas
# http://api.openweathermap.org/data/2.5/weather?&q=yurimaguas
# Processing Record 542 | bridlington
# http://api.openweathermap.org/data/2.5/weather?&q=bridlington
# Processing Record 543 | kampene
# http://api.openweathermap.org/data/2.5/weather?&q=kampene
# Processing Record 544 | marivan
# http://api.openweathermap.org/data/2.5/weather?&q=marivan
# Processing Record 545 | lubango
# http://api.openweathermap.org/data/2.5/weather?&q=lubango
# Processing Record 546 | gurupi
# http://api.openweathermap.org/data/2.5/weather?&q=gurupi
# Processing Record 547 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 548 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?&q=mandalgovi
# Processing Record 549 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 550 | panzhihua
# http://api.openweathermap.org/data/2.5/weather?&q=panzhihua
# Processing Record 551 | karpogory
# http://api.openweathermap.org/data/2.5/weather?&q=karpogory
# Processing Record 552 | vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# City not found. Skipping...
# Processing Record 554 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# Processing Record 555 | bosaso
# http://api.openweathermap.org/data/2.5/weather?&q=bosaso
# Processing Record 556 | smithers
# http://api.openweathermap.org/data/2.5/weather?&q=smithers
# Processing Record 557 | nyuksenitsa
# http://api.openweathermap.org/data/2.5/weather?&q=nyuksenitsa
# Processing Record 558 | savalou
# http://api.openweathermap.org/data/2.5/weather?&q=savalou
# Processing Record 559 | verkhnechusovskiye gorodki
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnechusovskiye gorodki
# Processing Record 560 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?&q=leshukonskoye
# Processing Record 561 | kendari
# http://api.openweathermap.org/data/2.5/weather?&q=kendari
# Processing Record 562 | gilbues
# http://api.openweathermap.org/data/2.5/weather?&q=gilbues
# Processing Record 563 | talakan
# http://api.openweathermap.org/data/2.5/weather?&q=talakan
# Processing Record 564 | zhoucheng
# http://api.openweathermap.org/data/2.5/weather?&q=zhoucheng
# Processing Record 565 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?&q=wahiawa
# Processing Record 566 | burns lake
# http://api.openweathermap.org/data/2.5/weather?&q=burns lake
# Processing Record 567 | businga
# http://api.openweathermap.org/data/2.5/weather?&q=businga
# Processing Record 568 | manggar
# http://api.openweathermap.org/data/2.5/weather?&q=manggar
# Processing Record 569 | duma
# http://api.openweathermap.org/data/2.5/weather?&q=duma
# Processing Record 570 | otradnoye
# http://api.openweathermap.org/data/2.5/weather?&q=otradnoye
# Processing Record 571 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 572 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?&q=ketchikan
# Processing Record 573 | luchegorsk
# http://api.openweathermap.org/data/2.5/weather?&q=luchegorsk
# Processing Record 574 | okhansk
# http://api.openweathermap.org/data/2.5/weather?&q=okhansk
# City not found. Skipping...
# Processing Record 576 | gayny
# http://api.openweathermap.org/data/2.5/weather?&q=gayny
# City not found. Skipping...
# Processing Record 578 | san miguel
# http://api.openweathermap.org/data/2.5/weather?&q=san miguel
# Processing Record 579 | sinop
# http://api.openweathermap.org/data/2.5/weather?&q=sinop
# Processing Record 580 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?&q=zhangjiakou
# Processing Record 581 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?&q=salinopolis
# Processing Record 582 | slave lake
# http://api.openweathermap.org/data/2.5/weather?&q=slave lake
# Processing Record 583 | necochea
# http://api.openweathermap.org/data/2.5/weather?&q=necochea
# Processing Record 584 | phuket
# http://api.openweathermap.org/data/2.5/weather?&q=phuket
# Processing Record 585 | mattru
# http://api.openweathermap.org/data/2.5/weather?&q=mattru
# Processing Record 586 | vadso
# http://api.openweathermap.org/data/2.5/weather?&q=vadso
# Processing Record 587 | tambovka
# http://api.openweathermap.org/data/2.5/weather?&q=tambovka
# Processing Record 588 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# City not found. Skipping...
# Processing Record 590 | ambon
# http://api.openweathermap.org/data/2.5/weather?&q=ambon
# Processing Record 591 | simga
# http://api.openweathermap.org/data/2.5/weather?&q=simga
# Processing Record 592 | corner brook
# http://api.openweathermap.org/data/2.5/weather?&q=corner brook
# Processing Record 593 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?&q=solnechnyy
# Processing Record 594 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 595 | gorom-gorom
# http://api.openweathermap.org/data/2.5/weather?&q=gorom-gorom
# Processing Record 596 | beloha
# http://api.openweathermap.org/data/2.5/weather?&q=beloha
# Processing Record 597 | hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 598 | tyukhtet
# http://api.openweathermap.org/data/2.5/weather?&q=tyukhtet
# Processing Record 599 | kokopo
# http://api.openweathermap.org/data/2.5/weather?&q=kokopo
# Processing Record 600 | ternate
# http://api.openweathermap.org/data/2.5/weather?&q=ternate
# Processing Record 601 | kipini
# http://api.openweathermap.org/data/2.5/weather?&q=kipini
# Processing Record 602 | buraydah
# http://api.openweathermap.org/data/2.5/weather?&q=buraydah
# Processing Record 603 | qeshm
# http://api.openweathermap.org/data/2.5/weather?&q=qeshm
# Processing Record 604 | kutum
# http://api.openweathermap.org/data/2.5/weather?&q=kutum
# Processing Record 605 | smolenka
# http://api.openweathermap.org/data/2.5/weather?&q=smolenka
# Processing Record 606 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?&q=olafsvik
# Processing Record 607 | verkh-usugli
# http://api.openweathermap.org/data/2.5/weather?&q=verkh-usugli
# Processing Record 608 | gardez
# http://api.openweathermap.org/data/2.5/weather?&q=gardez
# City not found. Skipping...
# Processing Record 610 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?&q=pundaguitan
#  ---------- Data Retrieval Complete ----------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary with the lists generated
weather_dict = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temperature": max_temp,
    "Humidity": humidity,
    "Wind Speed": wind_speed,
    "Cloudiness": cloudiness
}

# %%
# Create data frame
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               564
# Country            564
# Date               564
# Latitude           564
# Longitude          564
# Max Temperature    564
# Humidity           564
# Wind Speed         564
# Cloudiness         564
# dtype: int64

# %%
# Display dataframe
weather_data.head()
# Out:
#            City Country        Date  Latitude  Longitude  Max Temperature  \
# 0    Nelson Bay      AU  1617052969  -32.7167   152.1500            63.00
# 1      Tazovsky      RU  1617052679   67.4667    78.7000            -5.67
# 2  Puerto Ayora      EC  1617052912   -0.7393   -90.3518            82.40
# 3      Khatanga      RU  1617052820   71.9667   102.5000           -24.21
# 4        Kāvali      IN  1617052974   14.9167    79.9833            75.85
#
#    Humidity  Wind Speed  Cloudiness
# 0        94       10.36          75
# 1        88        5.01         100
# 2        78       11.50          20
# 3        97       12.08          28
# 4        86       10.47          95

# %%
# Save dataframe to CSV
weather_data.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
